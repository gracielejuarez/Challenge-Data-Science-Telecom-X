# %%
#O projeto tem como objetivo analisar os dados da Telecom X para identificar padrões e fatores associados à evasão. Para isso, serão utilizados Python e suas principais bibliotecas, aplicando o processo de ETL (extração, tratamento e organização dos dados), além da criação de visualizações e da realização de uma Análise Exploratória de Dados (EDA).

Os insights gerados apoiarão a tomada de decisões estratégicas e futuras etapas de modelagem preditiva, contribuindo para a redução do churn e aumento da fidelização.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import requests

# %% [markdown]
# #📌 Extracão

# %% [markdown]
# #🔧 Transformação

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# #📄Relatorio Final
